# %% [markdown]
# <a href="https://colab.research.google.com/github/Nada-Lahbib/GreenPubMed/blob/main/AI_PubMed.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data Preparation

# %%
# 1. Connecter Google Drive au notebook
from google.colab import drive
drive.mount('/content/drive')

# 2. Créer l'arborescence du projet dans ton Drive
import os

# On crée un dossier principal pour le hackathon dans ton Drive
project_path = '/content/drive/MyDrive/GreenPubMed_Hackathon'

# Liste des dossiers requis par le projet
folders = [
    f'{project_path}/data/bronze',
    f'{project_path}/data/silver',
    f'{project_path}/data/gold',
    f'{project_path}/src',
    f'{project_path}/notebooks',
    f'{project_path}/reports',
    f'{project_path}/app',
    f'{project_path}/slides'
]

# Création des dossiers s'ils n'existent pas
for folder in folders:
    os.makedirs(folder, exist_ok=True)

print(f"✅ Dossiers créés avec succès dans : {project_path}")
# Out:
# Mounted at /content/drive
# ✅ Dossiers créés avec succès dans : /content/drive/MyDrive/GreenPubMed_Hackathon

# %%
# Installation des dépendances du projet
# !pip install datasets pandas pyarrow polars codecarbon tiktoken
# !pip install sentence-transformers faiss-cpu scikit-learn streamlit matplotlib
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 380.8/380.8 kB 8.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.6/155.6 kB 10.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.8/51.8 kB 3.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.0/8.0 MB 66.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 77.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: psutil
#     Found existing installation: psutil 5.9.5
#     Uninstalling psutil-5.9.5:
#       Successfully uninstalled psutil-5.9.5
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.8/23.8 MB 63.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.2/9.2 MB 98.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 90.7 MB/s eta 0:00:00
# ...
